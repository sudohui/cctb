# %% [markdown]
# <a href="https://colab.research.google.com/github/sudohui/cctb/blob/main/assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/sudohui/cctb/refs/heads/main/imdb_movies_2024.csv'
# data = pd.read_csv('/content/imdb_movies_2024.csv')
data = pd.read_csv(url)
data.head()
# Out:
#                      Title                                         Movie Link  \
# 0          1. Inside Out 2  https://www.imdb.com/title/tt22022452/?ref_=sr...
# 1  2. Deadpool & Wolverine  https://www.imdb.com/title/tt6263850/?ref_=sr_t_2
# 2                3. Wicked  https://www.imdb.com/title/tt1262426/?ref_=sr_t_3
# 3               4. Moana 2  https://www.imdb.com/title/tt13622970/?ref_=sr...
# 4       5. Despicable Me 4  https://www.imdb.com/title/tt7510222/?ref_=sr_t_5
#
#    Year Duration MPA  Rating Votes
# 0  2024   1h 36m  PG     7.6  194K
# 1  2024    2h 8m   R     7.6  441K
# 2  2024   2h 40m  PG     7.9   90K
# 3  2024   1h 40m  PG     7.0   56K
# 4  2024   1h 34m  PG     6.2   55K

# %%
data.tail()
# Out:
#                     Title                                         Movie Link  \
# 595        596. Vettaiyan  https://www.imdb.com/title/tt26936666/?ref_=sr...
# 596           597. Nr. 24  https://www.imdb.com/title/tt23782584/?ref_=sr...
# 597         598. Parallel  https://www.imdb.com/title/tt14637386/?ref_=sr...
# 598  599. Fight or Flight  https://www.imdb.com/title/tt13652286/?ref_=sr...
# 599      600. A Sacrifice  https://www.imdb.com/title/tt16491560/?ref_=sr...
#
#      Year Duration  MPA  Rating Votes
# 595  2024   2h 43m  NaN     7.1   38K
# 596  2024   1h 51m  NaN     7.7  3.4K
# 597  2024   1h 28m  NaN     5.3  1.7K
# 598  2024   2h 46m  NaN     7.0   117
# 599  2024   1h 34m    R     5.1  4.3K

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       600 non-null    object
#  1   Movie Link  600 non-null    object
#  2   Year        600 non-null    int64
#  3   Duration    594 non-null    object
#  4   MPA         369 non-null    object
#  5   Rating      597 non-null    float64
#  6   Votes       597 non-null    object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 32.9+ KB

# %%
data.describe()
# Out:
#          Year      Rating
# count   600.0  597.000000
# mean   2024.0    6.288275
# std       0.0    1.249267
# min    2024.0    2.100000
# 25%    2024.0    5.400000
# 50%    2024.0    6.400000
# 75%    2024.0    7.100000
# max    2024.0    9.500000

# %%
data.columns.tolist()
# Out:
# ['Title', 'Movie Link', 'Year', 'Duration', 'MPA', 'Rating', 'Votes']

# %%
data.isnull().sum()
# Out:
# Title           0
# Movie Link      0
# Year            0
# Duration        6
# MPA           231
# Rating          3
# Votes           3
# dtype: int64

# %%
data.nunique()
# Out:
# Title         600
# Movie Link    600
# Year            1
# Duration       98
# MPA            13
# Rating         67
# Votes         316
# dtype: int64

# %%
data.isnull().sum()/len(data)*100
# Out:
# Title          0.0
# Movie Link     0.0
# Year           0.0
# Duration       1.0
# MPA           38.5
# Rating         0.5
# Votes          0.5
# dtype: float64

# %%
data.shape
# Out:
# (600, 7)

# %%
data.head(20)
# Out:
#                                     Title  \
# 0                         1. Inside Out 2
# 1                 2. Deadpool & Wolverine
# 2                               3. Wicked
# 3                              4. Moana 2
# 4                      5. Despicable Me 4
# 5              6. Beetlejuice Beetlejuice
# 6                       7. Dune: Part Two
# 7                             8. Twisters
# 8      9. Godzilla x Kong: The New Empire
# 9                     10. Kung Fu Panda 4
# 10              11. Bad Boys: Ride or Die
# 11               12. Sonic the Hedgehog 3
# 12  13. Kingdom of the Planet of the Apes
# 13                       14. Gladiator II
# 14              15. Mufasa: The Lion King
# 15                    16. It Ends with Us
# 16                     17. The Wild Robot
# 17              18. Venom: The Last Dance
# 18             19. A Quiet Place: Day One
# 19        20. Ghostbusters: Frozen Empire
#
# ...

# %%
data_cleaned = data.dropna()
data_cleaned.shape
# Out:
# (369, 7)

# %%
dadata = data.dropna(subset=['Rating'])
print(data.isnull().sum())
print(data.shape)
# Out:
# Title           0
# Movie Link      0
# Year            0
# Duration        6
# MPA           231
# Rating          3
# Votes           3
# dtype: int64
# (600, 7)
